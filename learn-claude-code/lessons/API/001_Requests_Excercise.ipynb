# %%
# %pip install anthropic python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()


# Create an API client
from anthropic import Anthropic
client = Anthropic()
model = "claude-sonnet-5"

# %%
# Make a request to the API
import anthropic

# Initialize the client (automatically looks for ANTHROPIC_API_KEY env variable)
client = anthropic.Anthropic()

response = client.messages.create(
    model=model,                          # Required: Target model
    max_tokens=1024,                     # Required: Max output tokens
    messages=[                           # Required: Array of message objects
        {
            "role": "user",
            "content": "Hello, Claude!"
        }
    ]
)

# response.content can include a ThinkingBlock before the TextBlock
# (adaptive thinking is on by default on this model), so find the
# first text block instead of assuming content[0] is text.
print(next(block.text for block in response.content if block.type == "text"))

# %%
def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages):
    response = client.messages.create(
        model=model,
        max_tokens=1024,
        messages=messages
    )
    # response.content can include a ThinkingBlock before the TextBlock
    # (adaptive thinking is on by default on this model), so find the
    # first text block instead of assuming content[0] is text.
    return next(block.text for block in response.content if block.type == "text")

# Make a start listing of messages
messages = []
# Add in the initial user message
add_user_message(messages, "Define Quantum Computing in one sentence.")

# Pass the message to chat() to get a response from the model
chat_response = chat(messages)

print(chat_response)
# Take the answer and add it to the messages list
add_assistant_message(messages, chat_response)
# Add in the user followup message
add_user_message(messages, "What are some potential applications of Quantum Computing?")
print(messages)
# Call chat() again with the list of messages to get the final answer from the model 
final_response = chat(messages)
print (final_response)

# %%
# Make an initial list of messages
messages = []

# Use while true loop to run the chat bot forever
while True:
    # Get user input
    user_input = input("> ")
    print("> " , user_input)

    # Add user input to the list of messages
    add_user_message(messages, user_input)
    print("Messages: ", messages)
    # Call Claude with Chat function
    answer = chat(messages)
    print("Messages: ", messages)
    # Add generated text to the list of messages
    add_assistant_message(messages, answer)
    # Print the generated text
    print("---")
    print(answer)
    print("---")
# Out:
# >  Add 1+1
# Messages:  [{'role': 'user', 'content': 'Add 1+1'}]
# Messages:  [{'role': 'user', 'content': 'Add 1+1'}]
# ---
# # 1 + 1 = 2
#
# That's basic addition! Combining one unit with another unit gives you a total of two units.
#
# Is there a specific context you're working with (like binary, different number bases, or a word problem)? Let me know if you need help with something more complex!
# ---
# >  add 2 more
# Messages:  [{'role': 'user', 'content': 'Add 1+1'}, {'role': 'assistant', 'content': "# 1 + 1 = 2\n\nThat's basic addition! Combining one unit with another unit gives you a total of two units.\n\nIs there a specific context you're working with (like binary, different number bases, or a word problem)? Let me know if you need help with something more complex!"}, {'role': 'user', 'content': 'add 2 more'}]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...
