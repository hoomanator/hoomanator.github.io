# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"],
}

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best excercise for losing weight? Please use the web search tool to find the answer and provide a summary of your findings.
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_011Cdk9SaxdoVos3qHs2TGvE', container=None, content=[ServerToolUseBlock(id='srvtoolu_01NeFdLF8H3gzf7DEFbwSeNV', caller=None, input={'query': 'best exercise for losing weight'}, name='web_search', type='server_tool_use'), WebSearchToolResultBlock(caller=DirectCaller(type='direct'), content=[WebSearchResultBlock(encrypted_content='...', page_age=None, title='Exercise for weight loss - PMC - NIH', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC6736437/'), WebSearchResultBlock(encrypted_content='', page_age=None, title='Role of Physical Activity for Weight Loss and ... - PMC - NIH', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC5556592/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Effect of exercise training on weight loss, body composition changes, and weight maintenance in adults with overweight or obesity: An overview of 12 systematic reviews and 149 studies - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC8365736/'), WebSearchResultBlock(encrypted_content='', page_age=None, title='Physical activity and exercise for weight loss and ...', type='web_search_result', url='https://pubmed.ncbi.nlm.nih.gov/37142892/'), WebSearchResultBlock(encrypted_content='...', page_age='May 20, 2026', title='Eating & Physical Activity to Lose or Maintain Weight - NIDDK', type='web_search_result', url='https://www.niddk.nih.gov/health-information/weight-management/adult-overweight-obesity/eating-physical-activity'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Effect of Exercise Training on Fat Loss—Energetic Perspectives and the Role of Improved Adipose Tissue Function and Body Fat Distribution - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC8497689/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Weight-Loss and Maintenance Strategies - Weight Management - NCBI Bookshelf', type='web_search_result', url='https://www.ncbi.nlm.nih.gov/books/NBK221839/'), WebSearchResultBlock(encrypted_content='', page_age=None, title='The Role of Exercise and Physical Activity in Weight Loss and ...', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC3925973/'), WebSearchResultBlock(encrypted_content='', page_age=None, title='Aerobic Exercise and Weight Loss in Adults - PMC - NIH', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC11672165/'), WebSearchResultBloc ...
