# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (0.120.2)
# Requirement already satisfied: python-dotenv in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from anthropic) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/hoomanator/claudetest/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic
client = Anthropic()
model = "claude-sonnet-4-5"

# %%
def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1024,
        "messages": messages,
        "temperature": temperature
    }

    if system:
        params["system"] = system
        
    response = client.messages.create(**params)
    # response.content can include a ThinkingBlock before the TextBlock
    # (adaptive thinking is on by default on this model), so find the
    # first text block instead of assuming content[0] is text.
    return next(block.text for block in response.content if block.type == "text")

# %%
# Make a start listing of messages
messages = []
system = """
    You are a patient math tutor.
    Do not directly answer a student's questions.
    Guide them to a solution step by step.
    """
# Add in the initial user message
add_user_message(messages, "Generate a one sentense movie idea")

# Pass the message to chat() to get a response from the model
answer = chat(messages, temperature=1.0)



print(answer)
# Out:
# A time traveler accidentally creates a world where humans hibernate for half the year, and must decide whether to fix the timeline or let humanity keep this strange new gift.
